# %% [markdown]
# <a href="https://colab.research.google.com/github/Nituhimani/Nituhimani/blob/main/GPTJ_lora_int8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [xturing](https://github.com/stochasticai/xturing) - GPTJ efficient fine-tuning tutorial
#
# This tutorial aims to show how easy it is to perform fine-tuning with xturing. This notebook shows how to finetune GPTJ 6B model on GPU

# %% [markdown]
# ## 1. Install the `xturing` library

# %%
# !pip install xturing --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 KB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 MB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 73.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 43.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.4/716.4 KB 29.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ## 2. Download and unzip the dataset

# %%
# !wget https://d33tr4pxdm6e2j.cloudfront.net/public_content/tutorials/datasets/alpaca_data.zip
# !unzip alpaca_data.zip
# Out:
# --2023-04-02 09:03:25--  https://d33tr4pxdm6e2j.cloudfront.net/public_content/tutorials/datasets/alpaca_data.zip
# Resolving d33tr4pxdm6e2j.cloudfront.net (d33tr4pxdm6e2j.cloudfront.net)... 99.84.170.151, 99.84.170.91, 99.84.170.126, ...
# Connecting to d33tr4pxdm6e2j.cloudfront.net (d33tr4pxdm6e2j.cloudfront.net)|99.84.170.151|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7395767 (7.1M) [application/zip]
# Saving to: ‘alpaca_data.zip’
#
# alpaca_data.zip     100%[===================>]   7.05M  --.-KB/s    in 0.1s
#
# 2023-04-02 09:03:25 (71.4 MB/s) - ‘alpaca_data.zip’ saved [7395767/7395767]
#
# Archive:  alpaca_data.zip
#    creating: alpaca_data/
#   inflating: alpaca_data/dataset_dict.json
#    creating: alpaca_data/train/
#   inflating: alpaca_data/train/data-00000-of-00001.arrow
#   inflating: alpaca_data/train/dataset_info.json
#   inflating: alpaca_data/train/state.json

# %% [markdown]
# ## 3. Load the dataset and initialize the model

# %%
from xturing.datasets.instruction_dataset import InstructionDataset
from xturing.models.base import BaseModel

instruction_dataset = InstructionDataset("/content/alpaca_data")
# Initializes the model
model = BaseModel.create("gptj_lora_int8")
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/13 [00:00<?, ?it/s]
# ...
# trainable params: 3670016 || all params: 6054552800 || trainable%: 0.060615806339982696

# %% [markdown]
# ## 4. Start the finetuning

# %%
# Finetuned the model
model.finetune(dataset=instruction_dataset)

# %% [markdown]
# ## 5. Generate an output text with the fine-tuned model

# %%
# Once the model has been finetuned, you can start doing inferences
output = model.generate(texts=["prime minister of India?"])
print("Generated output by the model: {}".format(output))
